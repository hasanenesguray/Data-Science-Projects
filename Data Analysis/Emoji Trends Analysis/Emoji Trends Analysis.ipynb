# %%
import pandas as pd

# Load the dataset
df_emoji = pd.read_csv('emoji_usage_dataset.csv')

# Display the first few rows and column names
print("Columns in the dataset:")
print(df_emoji.columns)
print("\nFirst few rows of the dataset:")
print(df_emoji.head())
# Out:
# Columns in the dataset:
# Index(['Emoji', 'Context', 'Platform', 'User Age', 'User Gender'], dtype='object')
#
# First few rows of the dataset:
#   Emoji      Context   Platform  User Age User Gender
# 0     😎        angry   Snapchat        47        Male
# 1     👍         love  Instagram        36        Male
# 2     😳        angry   Snapchat        51        Male
# 3     😂    confusion   Facebook        64        Male
# 4     🤣  celebration   Snapchat        56      Female
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Summary statistics for numerical columns
print("Summary statistics for numerical columns:")
print(df_emoji[['User Age']].describe())

# Summary statistics for categorical columns
print("\nSummary statistics for categorical columns:")
print(df_emoji[['Emoji', 'Context', 'Platform', 'User Gender']].describe())
# Out:
# Summary statistics for numerical columns:
#           User Age
# count  5000.000000
# mean     38.875600
# std      15.193179
# min      13.000000
# 25%      26.000000
# 50%      39.000000
# 75%      52.000000
# max      64.000000
#
# Summary statistics for categorical columns:
#        Emoji Context Platform User Gender
# count   5000    5000     5000        5000
# unique    30      10        6           2
# top        🤣    love  Twitter        Male
# freq     193     538      854        2537

# %%
import matplotlib.pyplot as plt

# Count occurrences of each emoji
emoji_counts = df_emoji['Emoji'].value_counts()

# Plot the distribution of emojis
plt.figure(figsize=(12, 8))
emoji_counts.plot(kind='bar', color=plt.get_cmap('Set1').colors)
plt.title('Distribution of Emojis')
plt.xlabel('Emoji')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()
# Out:
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129315 (\N{ROLLING ON THE FLOOR LAUGHING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128079 (\N{CLAPPING HANDS SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128591 (\N{PERSON WITH FOLDED HANDS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128149 (\N{TWO HEARTS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Plot the distribution of user ages
plt.figure(figsize=(12, 8))
plt.hist(df_emoji['User Age'].dropna(), bins=20, color='lightblue', edgecolor='black')
plt.title('Distribution of User Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Count occurrences of each context
context_counts = df_emoji['Context'].value_counts()

# Plot the distribution of contexts
plt.figure(figsize=(12, 8))
context_counts.plot(kind='bar', color=plt.get_cmap('Pastel1').colors)
plt.title('Distribution of Contexts')
plt.xlabel('Context')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()

# %%
# Count occurrences of each platform
platform_counts = df_emoji['Platform'].value_counts()

# Plot the distribution of platforms
plt.figure(figsize=(12, 8))
platform_counts.plot(kind='bar', color=plt.get_cmap('Paired').colors)
plt.title('Distribution of Platforms')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()

# %%
# Count occurrences of each gender
gender_counts = df_emoji['User Gender'].value_counts()

# Plot the distribution of user genders
plt.figure(figsize=(8, 8))
gender_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.get_cmap('Set2').colors)
plt.title('Distribution of User Genders')
plt.ylabel('')
plt.show()

# %%
# Check for missing values in the dataset
print("Missing values in each column:")
print(df_emoji.isnull().sum())
# Out:
# Missing values in each column:
# Emoji          0
# Context        0
# Platform       0
# User Age       0
# User Gender    0
# dtype: int64

# %%
import seaborn as sns

# Since there are no other numerical columns except 'User Age', correlation matrix will be limited
correlation_matrix = df_emoji[['User Age']].corr()

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix of Numerical Columns')
plt.show()

# %%
# Boxplot of Age by Emoji
plt.figure(figsize=(14, 10))
sns.boxplot(x='Emoji', y='User Age', data=df_emoji, palette='tab20')
plt.xticks(rotation=45, ha='right')
plt.title('Age Distribution by Emoji')
plt.xlabel('Emoji')
plt.ylabel('Age')
plt.grid(True)
plt.show()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_23373/1875518265.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Emoji', y='User Age', data=df_emoji, palette='tab20')
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129315 (\N{ROLLING ON THE FLOOR LAUGHING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128148 (\N{BROKEN HEART}) missing from font(s) DejaVu Sans.
# ...

# %%
# Boxplot of Age by Context
plt.figure(figsize=(14, 10))
sns.boxplot(x='Context', y='User Age', data=df_emoji, palette='Set2')
plt.xticks(rotation=45, ha='right')
plt.title('Age Distribution by Context')
plt.xlabel('Context')
plt.ylabel('Age')
plt.grid(True)
plt.show()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_23373/2317563456.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Context', y='User Age', data=df_emoji, palette='Set2')

# %%
# Boxplot of Age by Platform
plt.figure(figsize=(14, 10))
sns.boxplot(x='Platform', y='User Age', data=df_emoji, palette='Set1')
plt.xticks(rotation=45, ha='right')
plt.title('Age Distribution by Platform')
plt.xlabel('Platform')
plt.ylabel('Age')
plt.grid(True)
plt.show()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_23373/3223481513.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Platform', y='User Age', data=df_emoji, palette='Set1')

# %%
# Boxplot of Age by Gender
plt.figure(figsize=(12, 8))
sns.boxplot(x='User Gender', y='User Age', data=df_emoji, palette='pastel')
plt.title('Age Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.grid(True)
plt.show()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_23373/2000171341.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='User Gender', y='User Age', data=df_emoji, palette='pastel')

# %%
# Count occurrences of each emoji by platform
emoji_platform_counts = df_emoji.groupby('Platform')['Emoji'].value_counts().unstack().fillna(0)

# Plot the emoji usage by platform
plt.figure(figsize=(14, 10))
emoji_platform_counts.plot(kind='bar', stacked=True, colormap='tab20')
plt.title('Emoji Usage by Platform')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Emoji')
plt.grid(axis='y')
plt.show()
# Out:
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127881 (\N{PARTY POPPER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128079 (\N{CLAPPING HANDS SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128148 (\N{BROKEN HEART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Count occurrences of each emoji by context
emoji_context_counts = df_emoji.groupby('Context')['Emoji'].value_counts().unstack().fillna(0)

# Plot the emoji usage by context
plt.figure(figsize=(14, 10))
emoji_context_counts.plot(kind='bar', stacked=True, colormap='tab20')
plt.title('Emoji Usage by Context')
plt.xlabel('Context')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Emoji')
plt.grid(axis='y')
plt.show()
# Out:
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127881 (\N{PARTY POPPER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128079 (\N{CLAPPING HANDS SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128148 (\N{BROKEN HEART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
