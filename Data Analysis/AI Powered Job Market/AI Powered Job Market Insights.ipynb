# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("ai_job_market_insights.csv")
df.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium            High        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               Low             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_Title              500 non-null    object
#  1   Industry               500 non-null    object
#  2   Company_Size           500 non-null    object
#  3   Location               500 non-null    object
#  4   AI_Adoption_Level      500 non-null    object
#  5   Automation_Risk        500 non-null    object
#  6   Required_Skills        500 non-null    object
#  7   Salary_USD             500 non-null    float64
#  8   Remote_Friendly        500 non-null    object
#  9   Job_Growth_Projection  500 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 39.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#           Salary_USD
# count     500.000000
# mean    91222.390974
# std     20504.291453
# min     31969.526346
# 25%     78511.514863
# 50%     91998.195286
# 75%    103971.282092
# max    155209.821614

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Manufacturing         58
# Education             57
# Technology            56
# Finance               53
# Telecommunications    53
# Energy                49
# Entertainment         47
# Retail                46
# Healthcare            42
# Transportation        39
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='Industry')
plt.xlabel("Industry")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate the x-axis labels by 90 degrees
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='Company_Size')
plt.xlabel('Company_Size')
plt.ylabel('Count')
plt.show()

# %%
df['Location'].value_counts()
# Out:
# Location
# San Francisco    62
# Singapore        54
# Sydney           52
# Dubai            51
# Tokyo            51
# New York         49
# Berlin           48
# London           46
# Paris            46
# Toronto          41
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='Location')
plt.xlabel("Location")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate the x-axis labels by 90 degrees
plt.show()

# %%
df['AI_Adoption_Level'].value_counts()
# Out:
# AI_Adoption_Level
# Medium    179
# Low       174
# High      147
# Name: count, dtype: int64

# %% [markdown]
# * The data suggests that while AI is being adopted to some extent across the board, full adoption is still relatively rare. Most entities are in the early to mid-stages of AI integration, with only a minority having fully embraced AI technology. This could imply that there are barriers or hesitations in moving from low or medium adoption to high adoption levels.

# %%
df['Automation_Risk'].value_counts()
# Out:
# Automation_Risk
# Medium    173
# High      169
# Low       158
# Name: count, dtype: int64

# %% [markdown]
# * The data suggests that a significant proportion of jobs or processes are at risk of automation, with medium and high-risk levels being nearly equal. While there is still a portion of jobs or tasks with low automation risk, they are in the minority.

# %%
df['Required_Skills'].value_counts()
# Out:
# Required_Skills
# Project Management    60
# Python                60
# Cybersecurity         58
# Machine Learning      52
# UX/UI Design          49
# Sales                 49
# Data Analysis         49
# Marketing             45
# JavaScript            44
# Communication         34
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='Required_Skills')
plt.xlabel("Required_Skills")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate the x-axis labels by 90 degrees
plt.show()

# %% [markdown]
# * Top 3 Skills are - Project Management, Cybersecurity, Python it's surprising that communication, a skill traditionally considered crucial across almost all professions, isn't much required.

# %%
# Plotting the KDE for the Salary_USD column
df['Salary_USD'].plot(kind='kde', figsize=(10,6))

# Adding labels and title
plt.xlabel('Salary in USD')
plt.ylabel('Density')
plt.title('KDE Plot of Salary Distribution')

# Display the plot
plt.show()

# %%
df['Salary_USD'].plot(kind='hist', bins=30, figsize=(10,6), edgecolor='black')
plt.xlabel('Salary in USD')
plt.ylabel('Frequency')
plt.title('Histogram of Salary Distribution')
plt.show()

# %%
df['Salary_USD'].plot(kind='box', vert=False, figsize=(10,6))
plt.xlabel('Salary in USD')
plt.title('Box Plot of Salary Distribution')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.violinplot(x=df['Salary_USD'])
plt.xlabel('Salary in USD')
plt.title('Violin Plot of Salary Distribution')
plt.show()

# %%
df['Remote_Friendly'].value_counts()
# Out:
# Remote_Friendly
# Yes    251
# No     249
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Remote_Friendly')
# Out:
# <Axes: xlabel='Remote_Friendly', ylabel='count'>

# %% [markdown]
# * The nearly equal distribution between remote-friendly and non-remote-friendly roles suggests that the acceptance of remote work is fairly balanced in this dataset.

# %%
df['Job_Growth_Projection'].value_counts()
# Out:
# Job_Growth_Projection
# Growth     169
# Decline    169
# Stable     162
# Name: count, dtype: int64

# %% [markdown]
# * The distribution indicates a balanced outlook in the job market, with equal numbers of jobs projected to either grow or decline. This suggests a dynamic environment where some roles are on the rise while others may be shrinking or evolving.
