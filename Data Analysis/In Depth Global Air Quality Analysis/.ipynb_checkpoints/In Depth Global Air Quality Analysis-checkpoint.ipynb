# %%
import pandas as pd

# Load the dataset
file_path = 'global_air_quality_data_10000.csv'
df_air_quality = pd.read_csv(file_path)

# Display the first few rows
df_air_quality.head()
# Out:
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#              City   Country        Date   PM2.5    PM10    NO2    SO2    CO  \
# 0         Bangkok  Thailand  2023-03-19   86.57   25.19  99.88  30.63  4.46
# 1        Istanbul    Turkey  2023-02-16   50.63   97.39  48.14   8.71  3.40
# 2  Rio de Janeiro    Brazil  2023-11-13  130.21   57.22  98.51   9.92  0.12
# 3          Mumbai     India  2023-03-16  119.70  130.52  10.96  33.03  7.74
# 4           Paris    France  2023-04-04   55.20   36.62  76.85  21.85  2.00
#
#        O3  Temperature  Humidity  Wind Speed
# 0   36.29        17.67     59.35       13.76
# 1  144.16         3.46     67.51        6.36
# 2  179.31        25.29     29.30       12.87
# 3   38.65        23.15     99.97        7.71
# 4   67.09        16.02     90.28       14.16

# %%
# Display column information and data types
df_air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         10000 non-null  object
#  1   Country      10000 non-null  object
#  2   Date         10000 non-null  object
#  3   PM2.5        10000 non-null  float64
#  4   PM10         10000 non-null  float64
#  5   NO2          10000 non-null  float64
#  6   SO2          10000 non-null  float64
#  7   CO           10000 non-null  float64
#  8   O3           10000 non-null  float64
#  9   Temperature  10000 non-null  float64
#  10  Humidity     10000 non-null  float64
#  11  Wind Speed   10000 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 937.6+ KB

# %%
# Display summary statistics of the dataset
df_air_quality.describe(include='all')
# Out:
#           City Country        Date         PM2.5          PM10           NO2  \
# count    10000   10000       10000  10000.000000  10000.000000  10000.000000
# unique      20      19         336           NaN           NaN           NaN
# top     Mumbai     USA  2023-02-01           NaN           NaN           NaN
# freq       540     962          50           NaN           NaN           NaN
# mean       NaN     NaN         NaN     77.448439    104.438161     52.198649
# std        NaN     NaN         NaN     41.927871     55.062396     27.320490
# min        NaN     NaN         NaN      5.020000     10.000000      5.010000
# 25%        NaN     NaN         NaN     41.185000     57.137500     28.347500
# 50%        NaN     NaN         NaN     77.725000    103.690000     52.100000
# 75%        NaN     NaN         NaN    113.392500    152.265000     75.705000
# max        NaN     NaN         NaN    149.980000    200.000000    100.000000
#
#                  SO2            CO            O3  Temperature      Humidity  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# unique           NaN           NaN           NaN          NaN           NaN
# top              NaN           NaN           NaN          NaN           NaN
# freq             NaN           NaN           NaN          NaN           NaN
# mean       25.344490      5.047984    106.031643     14.89715     55.078579
# std        14.091194      2.852625     55.081345     14.44380     25.982232
# min         1.000000      0.100000     10.040000    -10.00000     10.010000
# 25%        13.190000      2.560000     58.380000      2.25750     32.527500
# 50%        25.350000      5.090000    106.055000     14.75500     55.080000
# 75%        37.500000      7.480000    153.982500     27.38250     77.442500
# max        49.990000     10.000000    200.000000     40.00000     99.990000
#
#           Wind Speed
# count   10000.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       10.231636
# std         5.632628
# min         0.500000
# 25%         5.290000
# 50%        10.260000
# 75%        15.070000
# max        20.000000

# %%
# Check for missing values in the dataset
df_air_quality.isnull().sum()
# Out:
# City           0
# Country        0
# Date           0
# PM2.5          0
# PM10           0
# NO2            0
# SO2            0
# CO             0
# O3             0
# Temperature    0
# Humidity       0
# Wind Speed     0
# dtype: int64

# %%
# Confirm that missing values are handled
df_air_quality.isnull().sum()
# Out:
# City           0
# Country        0
# Date           0
# PM2.5          0
# PM10           0
# NO2            0
# SO2            0
# CO             0
# O3             0
# Temperature    0
# Humidity       0
# Wind Speed     0
# dtype: int64

# %%
# Summary of the dataset after cleaning
df_air_quality.describe(include='all')
# Out:
#           City Country        Date         PM2.5          PM10           NO2  \
# count    10000   10000       10000  10000.000000  10000.000000  10000.000000
# unique      20      19         336           NaN           NaN           NaN
# top     Mumbai     USA  2023-02-01           NaN           NaN           NaN
# freq       540     962          50           NaN           NaN           NaN
# mean       NaN     NaN         NaN     77.448439    104.438161     52.198649
# std        NaN     NaN         NaN     41.927871     55.062396     27.320490
# min        NaN     NaN         NaN      5.020000     10.000000      5.010000
# 25%        NaN     NaN         NaN     41.185000     57.137500     28.347500
# 50%        NaN     NaN         NaN     77.725000    103.690000     52.100000
# 75%        NaN     NaN         NaN    113.392500    152.265000     75.705000
# max        NaN     NaN         NaN    149.980000    200.000000    100.000000
#
#                  SO2            CO            O3  Temperature      Humidity  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# unique           NaN           NaN           NaN          NaN           NaN
# top              NaN           NaN           NaN          NaN           NaN
# freq             NaN           NaN           NaN          NaN           NaN
# mean       25.344490      5.047984    106.031643     14.89715     55.078579
# std        14.091194      2.852625     55.081345     14.44380     25.982232
# min         1.000000      0.100000     10.040000    -10.00000     10.010000
# 25%        13.190000      2.560000     58.380000      2.25750     32.527500
# 50%        25.350000      5.090000    106.055000     14.75500     55.080000
# 75%        37.500000      7.480000    153.982500     27.38250     77.442500
# max        49.990000     10.000000    200.000000     40.00000     99.990000
#
#           Wind Speed
# count   10000.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       10.231636
# std         5.632628
# min         0.500000
# 25%         5.290000
# 50%        10.260000
# 75%        15.070000
# max        20.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of PM2.5 values
plt.figure(figsize=(10, 6))
sns.histplot(df_air_quality['PM2.5'], bins=30, kde=True)
plt.title('Distribution of PM2.5')
plt.xlabel('PM2.5')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot PM2.5 values over time
plt.figure(figsize=(12, 6))
plt.plot(df_air_quality['Date'], df_air_quality['PM2.5'])
plt.title('PM2.5 Levels Over Time')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.show()

# %%
# Box plot of PM2.5 levels by city
plt.figure(figsize=(15, 8))
sns.boxplot(x='City', y='PM2.5', data=df_air_quality)
plt.title('PM2.5 Levels by City')
plt.xlabel('City')
plt.ylabel('PM2.5')
plt.xticks(rotation=90)
plt.show()

# %%
# Filter only numeric columns for correlation calculation
numeric_cols = df_air_quality.select_dtypes(include=['number'])

# Plot a heatmap of correlations between numeric variables
plt.figure(figsize=(12, 10))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Scatter plot of PM2.5 vs. PM10
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PM2.5', y='PM10', data=df_air_quality)
plt.title('Scatter Plot of PM2.5 vs. PM10')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.show()

# %%
# Group by city and compute mean of pollutants
city_pollutants_mean = df_air_quality.groupby('City')[['PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3']].mean()
city_pollutants_mean
# Out:
#                     PM2.5        PM10        NO2        SO2        CO  \
# City
# Bangkok         77.461483  103.933988  51.507154  25.575792  5.263928
# Beijing         78.627848  103.189877  51.621045  24.903258  5.093443
# Berlin          76.974277  104.373353  52.955607  24.509114  4.966166
# Cairo           76.888451  102.985373  50.055431  24.987863  5.127157
# Dubai           80.013692  103.891192  52.683038  24.964096  5.084346
# Istanbul        77.711220  103.140102  52.022439  25.769207  5.123171
# Johannesburg    77.666008  105.135125  53.146929  24.674261  5.093397
# London          77.614908  103.843804  52.334581  25.495501  4.954110
# Los Angeles     76.418169  105.539416  53.521207  26.148129  5.246881
# Madrid          75.434768  105.870077  52.144537  25.148301  4.885888
# Mexico City     78.855054  104.526868  50.863650  26.022138  5.141339
# Moscow          77.878610  105.936286  52.029876  26.110913  5.120996
# Mumbai          78.901167  105.841667  53.344074  25.029444  5.077556
# New York        77.857054  102.950538  51.001634  25.168903  4.987591
# Paris           74.694622  104.642761  53.818487  24.572127  4.940757
# Rio de Janeiro  75.669532  105.440876  52.103971  24.578330  4.906721
# Seoul           74.802471  104.997222  51.881801  25.012759  4.889559
# Sydney          78.933560  103.373951  52.474938  25.684033  5.023477
# Tokyo           78.867475  105.040937  52.672770  27.978635  5.101446
# Toronto         77.827645  103.867799  51.546834  24.802027  4.946544
#
#                         O3
# City
# Bangkok         101.003066
# Beijing         105.740225
# Berlin          102.929788
# Cairo           105.929882
# Dubai           106.395673
# Istanbul        106.177988
# Johannesburg    106.182898
# London          103.305440
# Los Angeles     105.043481
# Madrid          103.775830
# Mexico City     105.686285
# Moscow          107.294212
# Mumbai          106.643648
# New York        106.371849
# Paris           106.910020
# Rio de Janeiro  108.069308
# Seoul           107.024253
# Sydney          106.818436
# Tokyo           108.479491
# Toronto         110.850367

# %%
# Bar plot of mean PM2.5 levels by city
plt.figure(figsize=(15, 8))
city_pollutants_mean['PM2.5'].plot(kind='bar')
plt.title('Mean PM2.5 Levels by City')
plt.xlabel('City')
plt.ylabel('Mean PM2.5')
plt.xticks(rotation=90)
plt.show()

# %%
# Pair plot of selected pollutants
sns.pairplot(df_air_quality[['PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3']])
plt.suptitle('Pair Plot of Selected Pollutants', y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Example DataFrame creation (Replace this with your actual data loading step)
data = {
    'Date': pd.date_range(start='1/1/2020', periods=100, freq='D'),
    'PM2.5': np.random.rand(100) * 100,
    'OtherMetric': np.random.rand(100) * 50
}
df_air_quality = pd.DataFrame(data)

# Ensure the Date column is in datetime format and set it as the index
df_air_quality['Date'] = pd.to_datetime(df_air_quality['Date'])
df_air_quality.set_index('Date', inplace=True)

# Resample to monthly frequency and calculate the mean only for numeric columns
seasonal_trends = df_air_quality.resample('ME').mean(numeric_only=True)

# Plot the line plot of seasonal trends
plt.figure(figsize=(12, 8))
plt.plot(seasonal_trends)
plt.title('Seasonal Trends in Air Quality')
plt.xlabel('Month')
plt.ylabel('Mean Value')
plt.legend(seasonal_trends.columns, loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Example DataFrame creation (Replace this with your actual data loading step)
data = {
    'Date': pd.date_range(start='1/1/2020', periods=100, freq='D'),
    'Country': np.random.choice(['USA', 'China', 'India', 'Germany', 'Brazil'], 100),
    'PM2.5': np.random.rand(100) * 100,
    'PM10': np.random.rand(100) * 150,
    'NO2': np.random.rand(100) * 50,
    'SO2': np.random.rand(100) * 20,
    'CO': np.random.rand(100) * 10,
    'O3': np.random.rand(100) * 70,
    'OtherMetric': np.random.rand(100) * 50
}
df_air_quality = pd.DataFrame(data)

# Ensure the Date column is in datetime format and set it as the index
df_air_quality['Date'] = pd.to_datetime(df_air_quality['Date'])
df_air_quality.set_index('Date', inplace=True)

# Group by country and compute mean of pollutants
country_pollutants_mean = df_air_quality.groupby('Country')[['PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3']].mean()
print(country_pollutants_mean)

# Plot the mean values of pollutants by country
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))

pollutants = ['PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3']
for i, pollutant in enumerate(pollutants):
    row, col = divmod(i, 2)
    sns.barplot(x=country_pollutants_mean.index, y=country_pollutants_mean[pollutant], ax=axes[row, col])
    axes[row, col].set_title(f'Mean {pollutant} by Country')
    axes[row, col].set_xlabel('Country')
    axes[row, col].set_ylabel(f'Mean {pollutant}')

plt.tight_layout()
plt.show()
# Out:
#              PM2.5       PM10        NO2        SO2        CO         O3
# Country
# Brazil   48.922789  91.084143  25.014091  12.183558  6.506544  28.587352
# China    34.663610  65.300998  24.339045  10.061979  4.699888  38.215964
# Germany  43.010397  81.788671  20.282668   8.608849  4.839878  32.584329
# India    50.229672  70.920523  29.731048   6.511082  3.779967  40.473237
# USA      50.951558  89.720095  17.001224  10.264677  5.310448  37.683855

# %%
# Heatmap of mean pollutant levels by country
plt.figure(figsize=(15, 10))
sns.heatmap(country_pollutants_mean, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title('Mean Pollutant Levels by Country')
plt.xlabel('Pollutants')
plt.ylabel('Country')
plt.show()
