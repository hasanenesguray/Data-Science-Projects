# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/hasanenesguray/Desktop/Personal Projects with Python/EDA - Software Industry Salary/Data/Salary_Dataset_with_Extra_Features.csv")

# %%
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
a=df['Job Roles']
a=set(a)
b=set(df['Employment Status'])
print(b)
print(a)
print(df['Job Roles'].values)
# Out:
# {'Contractor', 'Full Time', 'Intern', 'Trainee'}
# {'Database', 'Backend', 'Web', 'Mobile', 'Frontend', 'Java', 'IOS', 'Python', 'Android', 'Testing', 'SDE'}
# ['Android' 'Android' 'Android' ... 'Web' 'Web' 'Web']

# %%
df.shape
# Out:
# (22770, 8)

# %%
df.isna().sum()
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22770 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
fig=plt.figure(figsize =(10,10))
sns.set(font_scale=1.25)
b=sns.barplot(data=df, x="Job Roles", y="Salary", hue="Employment Status",errorbar=None)
plt.xticks(rotation=30)
plt.legend(loc='upper right')
plt.show()

# %%
job_roles=df['Job Roles'].tolist()
q=[]
for i in a:
    q.append(job_roles.count(i))

fig=plt.figure(figsize =(7,7))
plt.pie(q,labels=a,autopct='%.0f%%')
plt.show()

# %%
companies = df["Company Name"].value_counts().head(50)
plt.figure(figsize=(12,15))
sns.barplot(y=companies.index, x=companies.values, palette='plasma')
plt.show()

# %%
sr = pd.Series(['New York', 'Chicago', 'Toronto', 'Lisbon', 'Rio', 'Chicago', 'Lisbon','Rio','New York'])
print(sr.value_counts().head())
# Out:
# New York    2
# Chicago     2
# Lisbon      2
# Rio         2
# Toronto     1
# dtype: int64

# %%
print(companies.head(50))
# Out:
# Tata Consultancy Services                    271
# Amazon                                       184
# Infosys                                      169
# Accenture                                    150
# Cognizant Technology Solutions               144
# Wipro                                        122
# IBM                                          122
# HCL Technologies                             102
# Capgemini                                    101
# Fresher                                      101
# Microsoft                                     96
# Google                                        80
# First Student                                 77
# Tech Mahindra                                 76
# ABC                                           66
# Oracle                                        65
# Mindtree                                      60
# Freelancer                                    57
# Dell Technologies                             55
# ...

# %%
c = df["Company Name"].value_counts().head(200)
plt.figure(figsize=(25,55))
sns.barplot(y=c.index, x=c.values, palette='plasma')
plt.show()

# %%
dataplot=sns.heatmap(df.corr(), annot=True)
  
# displaying heatmap
plt.show()

# %%
plt.boxplot(df["Salaries Reported"])
plt.show()

# %%
print(df["Job Title"].value_counts()['Android Developer'])
df.head(15)
df['Job Title']=df['Job Title'].str.split(' -').str[0]
# Out:
# 2029

# %%
df.head(15)
# Out:
#     Rating                             Company Name          Job Title  \
# 0      3.8                                   Sasken  Android Developer
# 1      4.5         Advanced Millennium Technologies  Android Developer
# 2      4.0                                Unacademy  Android Developer
# 3      3.8                       SnapBizz Cloudtech  Android Developer
# 4      4.4                   Appoids Tech Solutions  Android Developer
# 5      4.2                               Freelancer  Android Developer
# 6      3.7                            SQUARE N CUBE  Android Developer
# 7      3.1  Samsung R&D Institute India - Bangalore  Android Developer
# 8      3.7                     DXMinds Technologies  Android Developer
# 9      3.6          Endeavour Software Technologies  Android Developer
# 10     3.6                            Craft Silicon  Android Developer
# 11     3.9                   Baronford & Associates  Android Developer
# ...

# %%
print(df["Job Title"].value_counts()['Android Developer'])
# Out:
# 2228

# %%
fig=plt.figure(figsize =(15,8))
sal=df[['Salary']]
sns.boxplot(data=df, x="Job Roles", y="Rating", palette="plasma")
plt.show()

# %%
df.groupby('Job Roles')['Salary'].mean()
# Out:
# Job Roles
# Android     565911.003056
# Backend     748518.164154
# Database    958584.046243
# Frontend    610098.699954
# IOS         695254.248927
# Java        564709.907427
# Mobile      882282.971429
# Python      486022.791975
# SDE         853794.522302
# Testing     496298.188506
# Web         415451.947948
# Name: Salary, dtype: float64

# %%
df.groupby('Job Roles')['Rating'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%  max
# Job Roles
# Android    2945.0  3.893141  0.622397  1.0  3.6  4.0  4.3  5.0
# Backend    1194.0  4.016750  0.572186  1.0  3.7  4.0  4.4  5.0
# Database    865.0  3.825780  0.391896  1.0  3.7  3.8  4.0  5.0
# Frontend   2163.0  3.958784  0.566050  1.0  3.7  4.0  4.3  5.0
# IOS        1631.0  3.905303  0.585595  1.0  3.7  4.0  4.2  5.0
# Java       1858.0  3.849892  0.474126  1.0  3.7  3.9  4.1  5.0
# Mobile      245.0  3.976327  0.559943  1.0  3.7  4.0  4.3  5.0
# Python      947.0  3.965259  0.559945  1.0  3.8  4.0  4.2  5.0
# SDE        8183.0  3.939765  0.440156  1.0  3.8  4.0  4.2  5.0
# Testing    1740.0  3.828276  0.476648  1.0  3.6  3.9  4.1  5.0
# Web         999.0  3.935936  0.639686  1.0  3.7  4.0  4.3  5.0
